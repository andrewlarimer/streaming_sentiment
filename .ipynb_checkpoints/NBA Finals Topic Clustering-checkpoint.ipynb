# %%
import re
import numpy as np
import pandas as pd

from google.cloud import bigquery

from bert_serving.client import BertClient
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

from sklearn.cluster import KMeans
from sklearn.manifold import TSNE

from bokeh.plotting import figure, show, output_file
from bokeh.models import HoverTool,ColumnDataSource
import colorcet as cc

# %%
warriors_entities = [
    "Golden State","Warriors","Steve Kerr","Kevin Durant","Stephen Curry","DeMarcus Cousins",
    "Klay Thompson","Draymond Green","Andre Iguodala","Andrew Bogut","Damion Lee","Jordan Bell",
    "Shaun Livingston","Kevon Looney","Jonas Jerebko","Quinn Cook","Alfonzo McKinnie","Jacob Evans",
    "Damian Jones","Marcus Derrickson"
]

raptors_entities = [
    "Toronto","Raptors","Nick Nurse","Kawhi Leonard","Kyle Lowry","Jeremy Lin","Fred VanVleet",
    "Marc Gasol","Pascal Siakam","Danny Green","Serge Ibaka","OG Anunoby","Norman Powell",
    "Patrick McCaw""Chris Boucher","Jodie Meeks","Eric Moreland","Malcolm Miller","Jordan Loyd",
    "Nav Bhatia",
]

league_entities = [
    "NBA finals","NBA"
    ]

hashtags = [
    "#DubNation","#WeTheNorth","#Basketball","#Sports","#NBAFinals","#Warriors","#Raptors",
    "#GoldenState","#ESPN","#BBall","#Dunk","#Basket","#StephCurry","#KevinDurant",
    "#NBAbasketball","#GoldenStateWarriors","#Curry","#Hoops","#Player","#Game","#NBAhistory"
]

# %% [markdown]
# ### Generate Encodings
#
# Since we'll be getting a mean of the tweets' words, let's clean away stopwords to not be overwhelmed by those.

# %%
stopwords =    {"i", "me", "my", "myself", "we", "our", "ours", "ourselves", \
                "you", "your", "yours", "yourself", "yourselves", "he", "him", \
                "his", "himself", "she", "her", "hers", "herself", "it", "its", \
                "itself", "they", "them", "their", "theirs", "themselves", "what", \
                "which", "who", "whom", "this", "that", "these", "those", "am", "is", \
                "are", "was", "were", "be", "been", "being", "have", "has", "had", \
                "having", "do", "does", "did", "doing", "a", "an", "the", "and", \
                "but", "if", "or", "because", "as", "until", "while", "of", "at", \
                "by", "for", "with", "about", "against", "between", "into", \
                "through", "during", "before", "after", "above", "below", "to", \
                "from", "up", "down", "in", "out", "on", "off", "over", "under", \
                "again", "further", "then", "once", "here", "there", "when", "where", \
                "why", "how", "all", "any", "both", "each", "few", "more", "most", \
                "other", "some", "such", "no", "nor", "not", "only", "own", "same", \
                "so", "than", "s", "t", "can", "will", "just", "should", "", "fuck", "shit",
                "pussy", "bitch", "asshole", "bastard","ck"}

def clean_phrases(uncleaned_tweet, stopwords):
    cleaned_tokens = []
    for word in re.finditer(r'([a-z]+)\W', uncleaned_tweet.lower()):
        if word.group(1) not in stopwords:
            cleaned_tokens.append(word.group(1))
    return " ".join(cleaned_tokens)

# %%
# Initialize the BigQuery Client
client = bigquery.Client()

# %%
# Initialize the BERT as Service client
bc = BertClient(ip='127.0.0.1', port=5555)

# %%
# Perform a query.
QUERY = (
    """
    SELECT
        text, user.location
    FROM
        `myspringml2.nba_finals.nba_tweets_g3`
    WHERE
        text IS NOT NULL AND
        text NOT LIKE 'RT %'
    LIMIT 10000""")
query_job = client.query(QUERY)  # API request
rows = query_job.result()  # Waits for query to finish

# %%
raw_tweets = []
cleaned_tweets = []
compound_sentiments = []

analyzer = SentimentIntensityAnalyzer()

for row in rows:
    this_tweet_text = row.text
    cleaned_string = clean_phrases(this_tweet_text, stopwords)
    if cleaned_string:
        # Only add to the lists if we've successfully gotten a clean string
        raw_tweets.append(row.text)
        cleaned_tweets.append(cleaned_string)
        # Add sentiment score as well
        vs = analyzer.polarity_scores(this_tweet_text)
        compound_sentiments.append(vs['compound'])

# %%
# Get the encodings (the BERT server is set to REDUCE_MEAN so we will get an average
# of the encodings of each word.)
tweet_encodings = bc.encode(cleaned_tweets)
# Out:
# /Users/andrewlarimer/anaconda3/lib/python3.7/site-packages/bert_serving/client/__init__.py:285: UserWarning: some of your sentences have more tokens than "max_seq_len=25" set on the server, as consequence you may get less-accurate or truncated embeddings.
# here is what you can do:
# - disable the length-check by create a new "BertClient(check_length=False)" when you do not want to display this warning
# - or, start a new server with a larger "max_seq_len"
#   '- or, start a new server with a larger "max_seq_len"' % self.length_limit)

# %% [markdown]
# ### Clustering

# %%
N_CLUSTERS = 30

km = KMeans(n_clusters=N_CLUSTERS, max_iter=2400)

# %%
clust_labels = km.fit_predict(tweet_encodings)
seg_distances_to_all_ks = km.transform(tweet_encodings)
seg_distance_to_nearest_k = []
for i, label in enumerate(clust_labels):
    seg_distance_to_nearest_k.append(seg_distances_to_all_ks[i,label])

# %%
order_of_proximity_to_clust_centers = np.argsort(np.array(seg_distance_to_nearest_k))

# %% [markdown]
# ### Combining to Pandas Dataframe and Subsetting to the top 10% most indicative of their clusters

# %%
d = {
    'raw_tweets':raw_tweets,
    'clust_labels':clust_labels,
    'proximity_order':order_of_proximity_to_clust_centers,
    'tweet_encodings_idx':range(0,len(tweet_encodings)),
    'compound_sentiment':compound_sentiments
}

combined_df = pd.DataFrame(d)

# %%
# Filtering for to 10%

filter_cutoff = int(len(clust_labels) * .1) + 1

# %%
filtered_df = combined_df[combined_df.proximity_order <= filter_cutoff]

# %%
filtered_df.head()
# Out:
#                                            raw_tweets  clust_labels  \
# 15  Le propriétaire des Cavaliers Dan Gilbert se r...            14
# 17  “I don’t feel bad for Steph cause LeBron went ...            20
# 21  @BIGBOYCHILL Lmaoooo! I really love Toronto so...            20
# 26                                    Bucket. Bucket.            12
# 28  LeBron doesn’t want to be coached, so stop wit...            21
#
#     proximity_order  tweet_encodings_idx  compound_sentiment
# 15               41                   15              0.0000
# 17              428                   17             -0.5423
# 21              386                   21              0.6989
# 26              577                   26              0.0000
# 28              579                   28             -0.3749

# %% [markdown]
# ### Plotting on 2D Plot
#
# First we reduce the dimensions to 2 using a process called TSNE.

# %%
selected_encodings = tweet_encodings[filtered_df.tweet_encodings_idx]

reduced_dimensions_2 = TSNE(n_components=2).fit_transform(selected_encodings)
filtered_df.loc[:,'x'] = [i[0] for i in reduced_dimensions_2];
filtered_df.loc[:,'y'] = [i[1] for i in reduced_dimensions_2];

reduced_dimensions_1 = TSNE(n_components=1).fit_transform(selected_encodings)
filtered_df.loc[:,'z'] = [i[0] for i in reduced_dimensions_1];
# Out:
# /Users/andrewlarimer/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/andrewlarimer/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /Users/andrewlarimer/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/andrewlarimer/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
filtered_df
# Out:
#                                              raw_tweets  clust_labels  \
# 15    Le propriétaire des Cavaliers Dan Gilbert se r...            14
# 17    “I don’t feel bad for Steph cause LeBron went ...            20
# 21    @BIGBOYCHILL Lmaoooo! I really love Toronto so...            20
# 26                                      Bucket. Bucket.            12
# 28    LeBron doesn’t want to be coached, so stop wit...            21
# 43                                     @BR_NBA @NBA A G             9
# 46    😎 Raptors point guard Kyle Lowry pushed by a f...            11
# 49    I like Canada.\nI like Stamp Collecting.\nI li...            25
# 93    I hate Steph Curry but big respect to him for ...            23
# 109   #NBAFinals RT @RaptorsNationCP: Nick Nurse is ...             5
# 122   @EzanaTaddese @espn How did drake enable peopl...            25
# 124   @nicholsma658 @SportsCenter I’m not a warriors...             6
# 129        #BoardManGetsPaid!! \n2-1 series #WeTheNorth             5
# 130   Campamento Urbano de baloncesto en Valencia en...             7
# 132   Je vais prendre aussi de l'escrime cela doit ê...            14
# 140        Found the dumbest tweet of the day! Congrats            21
# 141                             Byeeeeeeee kevinnnnn😂😂😂            28
# 143        Despicable. \nWhat's wrong with people? 🤦‍♂️            21
# 146   Warriors fans in 2015 : you play with who you ...            11
# 151       Warriors still gonna win the series lol 🤷🏽‍♂️             4
# 154   @L69LIE u even if u said u aint gna shop in to...             1
# 176   @DoYouEvenLIf The end? Don’t know that yet. Go...             3
# 191   NBA: Leonard sues Nike in logo flap -- report:...             3
# 212   Warriors fans straight saying they need 5 all ...             4
# 215   @warriors Not over, heads high...chest out , G...             4
# 221               @MikDeangel @rikk_senpaii raptors @ 6            22
# 222   Not listening to your prediction anymore skip ...            15
# 232                       Lmaooooo i was waiting for it            28
# 251   2010-2016 2 titles with his Super Team FOH CLOWNS             9
# 254   Check out my broadcast from my PlayStation 4! ...            26
# ...                                                 ...           ...
# 9462  @Supreme_Gifs @NBA the refs for every finals g...            11
# 9463  Like I said. Klay is the most important player...            25
# 9466  I’m scared Steph might drop 50 tonight and the...            15
# 9469  These calls are fucking me up man, get it toge...            15
# 9471  Haha 😂 \nMore in a free game: https://t.co/vaB...             3
# 9476  My favorite thing about the NBA playoffs is th...            11
# 9477      No Kd and Klay goodluck #DubNation #NBAFinals            20
# 9486  And for 3 games "is Delly the Curry stopper?" ...            20
# 9488                                @Raptors 🐀zors 💩🤮👎🏽             0
# 9495  Golden State Warriors' Arena Plays Pusha-T's D...            26
# 9498             THEY JUST SHOWED BEY YASSSS #nbafinals             8
# 9508  @exoticnot4rn @NBA They already scored the oth...             4
# 9520  ‘Let it rip’: Danny Green follows through in a...            25
# 9539  In California, do they not have those special ...            23
# 9541  Timeout Toronto after one Warriors basket... a...             6
# 9548  If raptors played like this every game we woul...             8
# 9580  I don’t even care about the Raptors game right...             4
# 9589                       Ok. Raptors. We got this. 🙌🙌             0
# 9595  @whyctrI sIS that it’s Mitch marner from the T...            22
# 9607    @goknickstape How does he own the Raptors lol..            20
# 9612  Warriors will keep crying about the Refs. Leon...             3
# 9613  Oooh yeah okay Ibaka got away with that one lo...             1
# 9634  One of the worst things of watching the #NBAFi...            25
# 9635  Out of approximately 80 companies who applied ...             3
# 9637             Guard. Curry. \n\n#Raptors #WeTheNorth             0
# 9640  I don’t wanna hear warriors fans talk about re...            11
# 9646  @Devin_Heroux @CBCNews @CBCToronto @CBCCalgary...             6
# 9647  This Sunday 9th of June 7.30pm at an amazing S...             3
# 9659  Following @StarSports for #NBAFinals Game 3 .....            11
# 9662                Raptors, just win one in Oakland 🙏🏾             9
#
#       proximity_order  tweet_encodings_idx  compound_sentiment          x  \
# 15                 41                   15              0.0000  41.864017
# 17                428                   17             -0.5423 -11.868267
# 21                386                   21              0.6989   3.265311
# 26                577                   26              0.0000  10.330570
# 28                579                   28             -0.3749 -11.052497
# 43                804                   43              0.0000  -3.549524
# 46                229                   46              0.6486 -16.665897
# 49                183                   49              0.8481 -11.417602
# 93                612                   93              0.9468 -16.924686
# 109               537                  109             -0.2960   4.828117
# 122               939                  122              0.0000 -11.602988
# 124               138                  124             -0.2411   5.531563
# 129               258                  129              0.0000   4.794532
# 130               279                  130              0.0000  43.859665
# 132               396                  132              0.0000  42.395153
# 140               429                  140              0.1007  -5.087655
# 141               782                  141              0.0000   6.180887
# 143               706                  143             -0.4767   9.918879
# 146               831                  146              0.7119 -32.834602
# 151                19                  151              0.7650 -26.832718
# 154               534                  154              0.0000 -19.464260
# 176               768                  176             -0.1926  -0.294644
# 191               914                  191              0.0000  -3.960713
# 212               528                  212              0.2263 -32.796398
# 215               820                  215              0.0000 -33.292923
# 221                15                  221              0.0000  21.068089
# 222               117                  222              0.4215 -14.308902
# 232               205                  232              0.0000   5.586212
# 251               947                  251              0.5994  11.239601
# 254               639                  254              0.0000  -1.214127
# ...               ...                  ...                 ...        ...
# 9462              170                 9462             -0.4588 -14.127928
# 9463              285                 9463              0.1823 -11.892783
# 9466              262                 9466             -0.5187  -9.086598
# 9469              730                 9469              0.0000 -13.579287
# 9471              444                 9471              0.8583  -2.599251
# 9476              631                 9476              0.4588 -11.018356
# 9477              140                 9477             -0.2960 -12.679804
# 9486              245                 9486              0.0000 -15.606727
# 9488              135                 9488              0.0000  19.176367
# 9495              324                 9495              0.2500  -5.766786
# 9498              599                 9498              0.0000  -6.685689
# 9508              519                 9508             -0.7096 -28.125134
# 9520              794                 9520              0.0000 -12.607162
# 9539              805                 9539              0.1134 -24.049795
# 9541              657                 9541              0.3612  -7.737884
# 9548              538                 9548              0.2732  13.145479
# 9580              127                 9580              0.4767 -26.205000
# 9589              747                 9589              0.2960  14.972589
# 9595              530                 9595              0.0000  14.866721
# 9607              267                 9607              0.0000   7.495852
# 9612              490                 9612             -0.6908  -6.640769
# 9613               68                 9613              0.7096   2.290637
# 9634               61                 9634             -0.6249 -10.702926
# 9635              522                 9635              0.5994  -8.500902
# 9637              119                 9637              0.0000  12.150789
# 9640              561                 9640              0.5994 -24.769640
# 9646              394                 9646              0.0000   5.392343
# 9647              141                 9647              0.5859  -3.259177
# 9659              588                 9659              0.0000 -16.618317
# 9662              329                 9662              0.5859   7.580379
#
#               y          z
# 15    11.296360  33.460182
# 17    16.270046 -12.110106
# 21     9.574461  16.489031
# 26    29.069399   9.004966
# 28    17.373768 -11.762106
# 43   -27.288439  -5.594676
# 46   -11.774182  -7.903577
# 49     3.187245 -13.488012
# 93    10.944407 -14.957760
# 109   -7.938273  17.359179
# 122   -4.122556 -12.619021
# 124  -14.875591   0.680783
# 129    2.864695  15.103659
# 130    2.028313  29.018379
# 132   12.111087  33.460297
# 140   -0.354568  -3.104930
# 141    9.680161  16.705967
# 143   32.333378   6.116134
# 146   -4.065292 -26.258696
# 151   13.957164 -21.420265
# 154   22.105343 -15.899893
# 176   -0.000413  -1.597116
# 191  -10.931652  -3.002798
# 212   -3.970724 -26.159840
# 215    1.170505 -24.312889
# 221   -7.176160  15.778777
# 222   13.297476 -14.944324
# 232    9.233440  16.662560
# 251   -9.917105   1.588283
# 254  -14.212767  -1.283852
# ...         ...        ...
# 9462 -21.820351  -6.663516
# 9463  -2.118719 -13.200049
# 9466  15.231473 -17.377346
# 9469  17.620590 -16.177988
# 9471  -5.736716  -2.242916
# 9476 -17.369820  -6.927708
# 9477  26.262806 -11.341234
# 9486  -0.245744 -10.437149
# 9488 -13.958216   4.236262
# 9495 -14.372438  -4.045404
# 9498   6.963382 -14.142653
# 9508   0.382825 -21.128738
# 9520   1.601560 -13.247998
# 9539 -10.679350  -9.092496
# 9541 -19.901682  -5.536081
# 9548 -17.925768   5.205155
# 9580   5.433007 -20.118799
# 9589 -15.652206   5.219049
# 9595  -4.770939  12.422848
# 9607   4.702352  15.588949
# 9612  -4.789840  -3.439719
# 9613   9.371184  16.670687
# 9634   0.184392 -12.954865
# 9635  -1.272157  -3.141929
# 9637 -20.105610   3.817135
# 9640  -0.698820 -19.170729
# 9646 -12.729903   0.811730
# 9647  -6.827662  -2.450403
# 9659 -22.119318  -6.584580
# 9662 -26.063717   2.385307
#
# [969 rows x 8 columns]

# %%
# Set up our colors
nba_category_palette = cc.glasbey[:N_CLUSTERS]
fills = [nba_category_palette[clust] for clust in filtered_df.clust_labels]

# %% [markdown]
# ### Plot 1: 2D Topic Clustering

# %%
output_file('tweet_clusters_2dtopic.html')

source = ColumnDataSource(
        data=dict(x=filtered_df['x'],y=filtered_df['y'],
            tweet = filtered_df['raw_tweets'],
            fills = fills))

hover = HoverTool(tooltips=[("Text","@tweet")])

tsne_plot_a = figure(tools=[hover])
tsne_plot_a.scatter('x','y',source=source,fill_color='fills',fill_alpha=0.5,radius=.8,line_color=None)

show(tsne_plot_a)

# %%
output_file('tweet_clusters_1dsent_1dtopic.html')

source = ColumnDataSource(
        data=dict(x=filtered_df['z'],y=filtered_df['compound_sentiment'],
            tweet = filtered_df['raw_tweets'],
            fills = fills))

hover = HoverTool(tooltips=[("Text","@tweet")])

tsne_plot_b = figure(tools=[hover])
tsne_plot_b.scatter('x','y',source=source,fill_color='fills',fill_alpha=0.5,radius=.6,line_color=None)

show(tsne_plot_b)

# %%
from bokeh.embed import file_html
from bokeh.resources import CDN

# %%
html_a = file_html(tsne_plot_a, CDN)
print(html_a)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Application</title>
#
#
#
#
#         <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-1.0.2.min.css" type="text/css" />
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.0.2.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="61e3f4f4-01b7-4ac8-ab7b-141565779d67"></div>
#
#
#
#
#
#         <script type="application/json" id="4647">
#           {"7298d173-bfb9-4098-af58-c113421ba638":{"roots":{"references":[{"attributes":{},"id":"4435","type":"BasicTickFormatter"},{"attributes":{"callback":null,"tooltips":[["Text","@tweet"]]},"id":"4406","type":"HoverTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"field":"fills"},"line_color":{"value":null},"radius":{"units":"data","value":0.8},"x":{"field":"x"},"y":{"field":"y"}},"id":"4429","type":"Circle"},{"attributes":{"plot":null,"text":""},"id":"4433","type":"Title"},{"attributes":{},"id":"4417","type":"BasicTicker"},{"attributes":{},"id":"4439","type":"UnionRenderers"},{"attributes":{"callback":null},"id":"4408","type":"DataRange1d"},{"attributes":{"plot":{"id":"4407","subtype":"Figure","type":"Plot"},"ticker":{"id":"4417","type":"BasicTicker"}},"id":"4420","type":"Grid"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"4406","type":"HoverTool"}]},"id":"4426","type":"Toolbar"},{"attributes":{"formatter":{"id":"4435","type":"BasicTickFormatter"},"plot":{"id":"4407","subtype":"Figure","type":"Plot"},"ticker":{"id":"4417","type":"BasicTicker"}},"id":"4416","type":"LinearAxis"},{"attributes":{"source":{"id":"4405","type":"ColumnDataSource"}},"id":"4432","type":"CDSView"},{"attributes":{"callback":null,"data":{"fills":["#95b577","#004b00","#004b00","#a17569","#8e7900","#005659","#00fdcf","#9ae4ff","#edb8b8","#ff7ed1","#9ae4ff","#6b004f","#ff7ed1","#ffa52f","#95b577","#8e7900","#5900a3","#8e7900","#00fdcf","#97ff00","#8c3bff","#00acc6","#00acc6","#97ff00","#97ff00","#ff7266","#bf03b8","#5900a3","#005659","#eb0077","#d60000","#bf03b8","#ff7ed1","#645474","#004b00","#9ae4ff","#95b577","#a17569","#00acc6","#018700","#00acc6","#573b00","#5900a3","#8e7900","#645474","#8e7900","#0000dd","#00acc6","#6b004f","#5d7e66","#bcb6ff","#97ff00","#9ae4ff","#9ae4ff","#00acc6","#ff7ed1","#00fdcf","#95b577","#ff7266","#5900a3","#9ae4ff","#00acc6","#00fdcf","#8e7900","#00fdcf","#005659","#005659","#ff7266","#0774d8","#eb0077","#eb0077","#9ae4ff","#a57bb8","#eb0077","#a57bb8","#a57bb8","#00fdcf","#573b00","#d60000","#00fdcf","#ff7ed1","#00acc6","#fdf490","#bf03b8","#00acc6","#9ae4ff","#d60000","#573b00","#ff7ed1","#bf03b8","#eb0077","#8e7900","#ff7266","#bf03b8","#8c3bff","#97ff00","#bcb6ff","#a57bb8","#8e7900","#8e7900","#ff7ed1","#8e7900","#ff7ed1","#573b00","#00acc6","#790000","#00fdcf","#5900a3","#005659","#8e7900","#573b00","#8e7900","#004b00","#bf03b8","#a17569","#9ae4ff","#ff7266","#03c600","#573b00","#9ae4ff","#ff7ed1","#97ff00","#ff7ed1","#95b577","#fdf490","#ff7ed1","#645474","#bf03b8","#bf03b8","#9ae4ff","#8e7900","#edb8b8","#5900a3","#ff7266","#6b004f","#ff7ed1","#00acc6","#573b00","#ffa52f","#97ff00","#ff7ed1","#8c3bff","#8c3bff","#97ff00","#018700","#004b00","#6b004f","#edb8b8","#edb8b8","#004b00","#790000","#8c3bff","#018700","#fdf490","#8e7900","#97ff00","#97ff00","#0774d8","#d60000","#00fdcf","#ff7ed1","#5900a3","#bcb6ff","#00acc6","#573b00","#97ff00","#a17569","#edb8b8","#edb8b8","#bf03b8","#95b577","#0774d8","#bf03b8","#8c3bff","#645474","#bf03b8","#a57bb8","#ff7ed1","#d60000","#bcb6ff","#8e7900","#5d7e66","#00fdcf","#8e7900","#018700","#fdf490","#edb8b8","#bf03b8","#00fdcf","#eb0077","#edb8b8","#bcb6ff","#a57bb8","#00fdcf","#ff7266","#5d7e66","#ffa52f","#573b00","#bf03b8","#d60000","#790000","#6b004f","#a57bb8","#ffa52f","#bcb6ff","#03c600","#edb8b8","#004b00","#bcb6ff","#ff7266","#00fdcf","#00fdcf","#ff7ed1","#fdf490","#97ff00","#bf03b8","#8c3bff","#6b004f","#018700","#edb8b8","#8c3bff","#8c3bff","#8c3bff","#ff7ed1","#95b577","#bf03b8","#8e7900","#00fdcf","#005659","#5900a3","#004b00","#bf03b8","#004b00","#573b00","#ff7ed1","#00acc6","#a17569","#004b00","#9ae4ff","#004b00","#edb8b8","#a57bb8","#eb0077","#eb0077","#a17569","#0000dd","#ffa52f","#00fdcf","#5d7e66","#bf03b8","#ff7266","#0000dd","#573b00","#005659","#fdf490","#9ae4ff","#ff7266","#004b00","#8c3bff","#005659","#eb0077","#00fdcf","#edb8b8","#ff7ed1","#9ae4ff" ...
#         </script>
#         <script type="text/javascript">
#           (function() {
#             var fn = function() {
#               Bokeh.safely(function() {
#                 (function(root) {
#                   function embed_document(root) {
#
#                   var docs_json = document.getElementById('4647').textContent;
#                   var render_items = [{"docid":"7298d173-bfb9-4098-af58-c113421ba638","roots":{"4407":"61e3f4f4-01b7-4ac8-ab7b-141565779d67"}}];
#                   root.Bokeh.embed.embed_items(docs_json, render_items);
#
#                   }
#                   if (root.Bokeh !== undefined) {
#                     embed_document(root);
#                   } else {
#                     var attempts = 0;
#                     var timer = setInterval(function(root) {
#                       if (root.Bokeh !== undefined) {
#                         embed_document(root);
#                         clearInterval(timer);
#                       }
#                       attempts++;
#                       if (attempts > 100) {
#                         console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#                         clearInterval(timer);
#                       }
#                     }, 10, root)
#                   }
#                 })(window);
#               });
#             };
#             if (document.readyState != "loading") fn();
#             else document.addEventListener("DOMContentLoaded", fn);
#           })();
#         </script>
#
#   </body>
#
# </html>

# %%
html_b = file_html(tsne_plot_b, CDN)
print(html_b)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>Bokeh Application</title>
#
#
#
#
#         <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-1.0.2.min.css" type="text/css" />
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.0.2.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="6143315f-ccca-4a2b-b6d6-a81022b743d3"></div>
#
#
#
#
#
#         <script type="application/json" id="4704">
#           {"5b8731d5-6322-47f3-b243-4c7e561532c1":{"roots":{"references":[{"attributes":{},"id":"4530","type":"BasicTickFormatter"},{"attributes":{},"id":"4507","type":"LinearScale"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"field":"fills"},"line_color":{"value":null},"radius":{"units":"data","value":0.6},"x":{"field":"x"},"y":{"field":"y"}},"id":"4522","type":"Circle"},{"attributes":{"below":[{"id":"4509","type":"LinearAxis"}],"left":[{"id":"4514","type":"LinearAxis"}],"renderers":[{"id":"4509","type":"LinearAxis"},{"id":"4513","type":"Grid"},{"id":"4514","type":"LinearAxis"},{"id":"4518","type":"Grid"},{"id":"4524","type":"GlyphRenderer"}],"title":{"id":"4526","type":"Title"},"toolbar":{"id":"4519","type":"Toolbar"},"x_range":{"id":"4501","type":"DataRange1d"},"x_scale":{"id":"4505","type":"LinearScale"},"y_range":{"id":"4503","type":"DataRange1d"},"y_scale":{"id":"4507","type":"LinearScale"}},"id":"4500","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"4505","type":"LinearScale"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_multi":null,"active_scroll":"auto","active_tap":"auto","tools":[{"id":"4499","type":"HoverTool"}]},"id":"4519","type":"Toolbar"},{"attributes":{"plot":null,"text":""},"id":"4526","type":"Title"},{"attributes":{"callback":null},"id":"4501","type":"DataRange1d"},{"attributes":{},"id":"4533","type":"Selection"},{"attributes":{"dimension":1,"plot":{"id":"4500","subtype":"Figure","type":"Plot"},"ticker":{"id":"4515","type":"BasicTicker"}},"id":"4518","type":"Grid"},{"attributes":{"callback":null},"id":"4503","type":"DataRange1d"},{"attributes":{},"id":"4528","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"4530","type":"BasicTickFormatter"},"plot":{"id":"4500","subtype":"Figure","type":"Plot"},"ticker":{"id":"4515","type":"BasicTicker"}},"id":"4514","type":"LinearAxis"},{"attributes":{},"id":"4515","type":"BasicTicker"},{"attributes":{"source":{"id":"4498","type":"ColumnDataSource"}},"id":"4525","type":"CDSView"},{"attributes":{"callback":null,"tooltips":[["Text","@tweet"]]},"id":"4499","type":"HoverTool"},{"attributes":{"plot":{"id":"4500","subtype":"Figure","type":"Plot"},"ticker":{"id":"4510","type":"BasicTicker"}},"id":"4513","type":"Grid"},{"attributes":{},"id":"4532","type":"UnionRenderers"},{"attributes":{"data_source":{"id":"4498","type":"ColumnDataSource"},"glyph":{"id":"4522","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4523","type":"Circle"},"selection_glyph":null,"view":{"id":"4525","type":"CDSView"}},"id":"4524","type":"GlyphRenderer"},{"attributes":{},"id":"4510","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.6},"x":{"field":"x"},"y":{"field":"y"}},"id":"4523","type":"Circle"},{"attributes":{"callback":null,"data":{"fills":["#95b577","#004b00","#004b00","#a17569","#8e7900","#005659","#00fdcf","#9ae4ff","#edb8b8","#ff7ed1","#9ae4ff","#6b004f","#ff7ed1","#ffa52f","#95b577","#8e7900","#5900a3","#8e7900","#00fdcf","#97ff00","#8c3bff","#00acc6","#00acc6","#97ff00","#97ff00","#ff7266","#bf03b8","#5900a3","#005659","#eb0077","#d60000","#bf03b8","#ff7ed1","#645474","#004b00","#9ae4ff","#95b577","#a17569","#00acc6","#018700","#00acc6","#573b00","#5900a3","#8e7900","#645474","#8e7900","#0000dd","#00acc6","#6b004f","#5d7e66","#bcb6ff","#97ff00","#9ae4ff","#9ae4ff","#00acc6","#ff7ed1","#00fdcf","#95b577","#ff7266","#5900a3","#9ae4ff","#00acc6","#00fdcf","#8e7900","#00fdcf","#005659","#005659","#ff7266","#0774d8","#eb0077","#eb0077","#9ae4ff","#a57bb8","#eb0077","#a57bb8","#a57bb8","#00fdcf","#573b00","#d60000","#00fdcf","#ff7ed1","#00acc6","#fdf490","#bf03b8","#00acc6","#9ae4ff","#d60000","#573b00","#ff7ed1","#bf03b8","#eb0077","#8e7900","#ff7266","#bf03b8","#8c3bff","#97ff00","#bcb6ff","#a57bb8","#8e7900","#8e7900","#ff7ed1","#8e7900","#ff7ed1","#573b00","#00acc6","#7 ...
#         </script>
#         <script type="text/javascript">
#           (function() {
#             var fn = function() {
#               Bokeh.safely(function() {
#                 (function(root) {
#                   function embed_document(root) {
#
#                   var docs_json = document.getElementById('4704').textContent;
#                   var render_items = [{"docid":"5b8731d5-6322-47f3-b243-4c7e561532c1","roots":{"4500":"6143315f-ccca-4a2b-b6d6-a81022b743d3"}}];
#                   root.Bokeh.embed.embed_items(docs_json, render_items);
#
#                   }
#                   if (root.Bokeh !== undefined) {
#                     embed_document(root);
#                   } else {
#                     var attempts = 0;
#                     var timer = setInterval(function(root) {
#                       if (root.Bokeh !== undefined) {
#                         embed_document(root);
#                         clearInterval(timer);
#                       }
#                       attempts++;
#                       if (attempts > 100) {
#                         console.log("Bokeh: ERROR: Unable to run BokehJS code because BokehJS library is missing");
#                         clearInterval(timer);
#                       }
#                     }, 10, root)
#                   }
#                 })(window);
#               });
#             };
#             if (document.readyState != "loading") fn();
#             else document.addEventListener("DOMContentLoaded", fn);
#           })();
#         </script>
#
#   </body>
#
# </html>
